# %% [markdown]
# # Exercises

# %%
from acquire import get_blog_articles, get_news_article
import unicodedata
import re
import json

import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd
# Out:
# [nltk_data] Downloading package wordnet to /Users/jay/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/jay/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ## Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# - Lowercase everything
# - Normalize unicode characters
# - Replace anything that is not a letter, number, whitespace or a single quote.

# %%
def basic_clean(string_cleaning):
    '''
    basic clean will take in a string and after making all characters lower case and making sure only ASCII characters 
    will return the cleaned string
    '''
    string_cleaning = string_cleaning.lower()
    string_cleaning = re.sub(r"[^a-z0-9'\s]", '', string_cleaning)
    return string_cleaning

# %%
basic_clean("If there were 40 people, and 38 apples, then 2 didn't. Alternatively, let's say there were 313 people at a dinner party, and 98 salads, so 215 didn't. One more, if there were 33 cats, and 28 mice, how many didn't?")
# Out:
# "if there were 40 people and 38 apples then 2 didn't alternatively let's say there were 313 people at a dinner party and 98 salads so 215 didn't one more if there were 33 cats and 28 mice how many didn't"

# %% [markdown]
# ## Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(string_cleaning):
    '''
    tokenize will take in a string and return the string tokenized
    '''
    tokenizer = nltk.tokenize.ToktokTokenizer()
    return tokenizer.tokenize(string_cleaning, return_str=True)

# %%
tokenize("if there were 40 people and 38 apples then 2 didn't alternatively let's say there were 313 people at a dinner party and 98 salads so 215 didn't one more if there were 33 cats and 28 mice how many didn't")
# Out:
# "if there were 40 people and 38 apples then 2 didn ' t alternatively let ' s say there were 313 people at a dinner party and 98 salads so 215 didn ' t one more if there were 33 cats and 28 mice how many didn ' t"

# %% [markdown]
# ## Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string_cleaning):
    '''
    stem will take in a string and return the string after stemming
    '''
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in string_cleaning.split()]
    spring_cleaning_stemmed = ' '.join(stems)
    return spring_cleaning_stemmed

# %%
stem("if there were 40 people and 38 apples then 2 didn ' t alternatively let ' s say there were 313 people at a dinner party and 98 salads so 215 didn ' t one more if there were 33 cats and 28 mice how many didn ' t")
# Out:
# "if there were 40 peopl and 38 appl then 2 didn ' t altern let ' s say there were 313 peopl at a dinner parti and 98 salad so 215 didn ' t one more if there were 33 cat and 28 mice how mani didn ' t"

# %% [markdown]
# ## Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(string_cleaning):
    '''
    lemmatize will take in a string and return the string after lemmatizing it
    '''
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in string_cleaning.split()]
    spring_cleaning_lemmatized = ' '.join(lemmas)
    return spring_cleaning_lemmatized

# %%
lemmatize("if there were 40 people and 38 apples then 2 didn ' t alternatively let ' s say there were 313 people at a dinner party and 98 salads so 215 didn ' t one more if there were 33 cats and 28 mice how many didn ' t")
# Out:
# "if there were 40 people and 38 apple then 2 didn ' t alternatively let ' s say there were 313 people at a dinner party and 98 salad so 215 didn ' t one more if there were 33 cat and 28 mouse how many didn ' t"

# %% [markdown]
# ## Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.
# - This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
extra_words = ['dinner', 'salad']

# %%
stopword_list = stopwords.words('english')
stopword_list = stopword_list + [extra_words]
stopword_list[-1]
# Out:
# ['dinner', 'salad']

# %%
def remove_stopwords(string_cleaning, extra_words='', exclude_words=''):
    '''
    remove_stopwords will take in a string, any extra words to be removed, and and words to keep, and return the string with stop words removed
    '''
    stopword_list = stopwords.words('english')
    stopword_list = stopword_list.remove(exclude_words)
    stopword_list = [stopword_list] + [extra_words]
    words = string_cleaning.split()
    filtered_words = [w for w in words if w not in stopword_list]
    string_without_stopwords = ' '.join(filtered_words)
    return string_without_stopwords

# %%
remove_stopwords("if there were 40 people and 38 apple then 2 didn ' t alternatively let ' s say there were 313 people at a dinner party and 98 salad so 215 didn ' t one more if there were 33 cat and 28 mouse how many didn ' t", ['dinner', 'salad'], 'if')
# Out:
# "if there were 40 people and 38 apple then 2 didn ' t alternatively let ' s say there were 313 people at a dinner party and 98 salad so 215 didn ' t one more if there were 33 cat and 28 mouse how many didn ' t"

# %% [markdown]
# ## Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
news_df = get_news_article()
news_df
# Out:
#                                                 title  \
# 0   Victoria's Secret ex-CEO cuts Harvard ties for...
# 1   HDFC Bank's Vigil Aunty ad gets criticism for ...
# 2   IMEC big opportunity for investors to partner ...
# 3   ICICI Bank fined ₹12 crore, Kotak ₹3.95 crore ...
# 4   35 lakh weddings in 23 days to generate record...
# 5   Mahadev app key accused arrives from Dubai, he...
# 6   Bankman-Fried's trial delay request over Adder...
# 7                Indian wheat prices hit 8-month high
# 8             Dabur gets ₹321 crore GST demand notice
# 9   'Kill list' of LinkedIn staff being fired was ...
# 10  Planned to make 'Jab...' with Bobby, 'Highway'...
# 11  Ranbir asks photographers to be careful as the...
# 12  Don't break your bank: Zeenat to youngsters on...
# 13  'Kabhi Khushi...' had really bad reviews, I wa...
# 14  Emotional moment: Sandeepa on visiting Kashmir...
# 15  Won't work with Sivakarthikeyan again, he betr...
# 16  What a shame, I'm going to erase today: Direct...
# 17  Kriti Sanon, Allu Arjun's selfie in 'Pushpa' p...
# 18  Taylor Swift's Eras tour security guard joins ...
# 19  Pics show Alia, Ranbir, Kriti, Allu Arjun inte...
# 20  Palestinian, Arab, Muslim Googlers deeply affe...
# 21  Russia fines Zoom $1.18mn for working without ...
# 22  US restricts sale of more advanced AI chips to...
# 23  Apple unveils new Pencil with USB-C port costi...
# 24  Apple's cheaper headset to have less sensors, ...
# 25  Dubai Police unveils driverless, AI-powered pa...
# 26  Bankman-Fried's trial delay request over Adder...
# 27  'Apple AirTag led to multiple murders,' claims...
# 28  'Kill list' of LinkedIn staff being fired was ...
# 29  Facebook, YouTube, Google suppress pro-Palesti...
# 30  Netherlands defeat South Africa in another ups...
# 31  People would tell my parents 'Don't allow her ...
# 32  Are Netherlands doing them in again: Harsha on...
# 33  Rishabh Pant shares video of him running on tr...
# 34  Sri Lanka Cricket lifts ban on Gunathilaka aft...
# 35  Exceptional bowling: Uthappa as SA lose 4 batt...
# 36  PCB files complaint over crowd conduct against...
# 37  Game vs SA could be over before powerplay if E...
# 38  I have never seen Rauf pick wickets like Bumra...
# 39  3 of Netherlands' cricketers playing against S...
#
#                                                  body       category
# 0   Victoria's Secret ex-CEO Leslie Wexner's found...       business
# 1   HDFC Bank's latest advertisement featuring Vig...       business
# 2   PM Narendra Modi at the Global Maritime India ...       business
# 3   The Reserve Bank of India (RBI) has imposed a ...       business
# 4   Traders' body Confederation of All India Trade...       business
# 5   Mrugank Mishra, a key accused in Mahadev betti...       business
# 6   A US court denied FTX Founder Sam Bankman-Frie...       business
# 7   Prices of wheat in India have reached an eight...       business
# 8   Dabur India has received a notice to pay Goods...       business
# 9   A list with names of about 500 employees was l...       business
# 10  Filmmaker Imtiaz Ali revealed that he was plan...  entertainment
# 11  Veteran actress Waheeda Rehman was honoured wi...  entertainment
# 12  Actress Zeenat Aman took to Instagram to share...  entertainment
# 13  Filmmaker Karan Johar said that he was "very d...  entertainment
# 14  Actress Sandeepa Dhar, who was just two when h...  entertainment
# 15  Music composer D Imman said that he will never...  entertainment
# 16  Filmmaker and gay rights activist Onir, expres...  entertainment
# 17  Kriti Sanon received the Best Actress award at...  entertainment
# 18  A security guard who provided protection to si...  entertainment
# 19  The 69th National Film Awards ceremony was hel...  entertainment
# 20  Google CEO Sundar Pichai in an e-mail to emplo...     technology
# 21  Russia has imposed a $1.18 million fine on Zoo...     technology
# 22  The US on Tuesday unveiled plans to restrict t...     technology
# 23  Apple on Tuesday unveiled the new Apple Pencil...     technology
# 24  Apple is reportedly planning to use fewer exte...     technology
# 25  Dubai Police has unveiled a "self-driving" pat...     technology
# 26  A US court denied FTX Founder Sam Bankman-Frie...     technology
# 27  Apple is facing a class action lawsuit in US t...     technology
# 28  A list with names of about 500 employees was l...     technology
# 29  Think tank Hampton Institute alleged that soci...     technology
# 30  Netherlands, the lowest-ranked team in the ong...         sports
# 31  Table tennis player Sutirtha Mukherjee, who al...         sports
# 32  Commentator Harsha Bhogle took to X to state t...         sports
# 33  Wicketkeeper-batter Rishabh Pant, who is under...         sports
# 34  Sri Lanka Cricket (SLC) has lifted ban on Danu...         sports
# 35  Reacting to South Africa losing four batters w...         sports
# 36  The PCB has filed a complaint regarding inappr...         sports
# 37  Former England batter Mark Butcher said Englan...         sports
# 38  Ex-Pakistan captain Wasim Akram said he has ne...         sports
# 39  Netherlands' Sybrand Engelbrecht, Colin Ackerm...         sports

# %% [markdown]
# ## Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
codeup_df = get_blog_articles()
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              article
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...

# %% [markdown]
# ## For each dataframe, produce the following columns:
# - title to hold the title
# - original to hold the original article/post content
# - clean to hold the normalized and tokenized original with the stopwords removed.
# - stemmed to hold the stemmed version of the cleaned data.
# - lemmatized to hold the lemmatized version of the cleaned data.

# %% [markdown]
# ### News

# %%
# let's store the dataframe here for easier access
news_df = get_news_article()
news_df
# Out:
#                                                 title  \
# 0   Victoria's Secret ex-CEO cuts Harvard ties for...
# 1   HDFC Bank's Vigil Aunty ad gets criticism for ...
# 2   IMEC big opportunity for investors to partner ...
# 3   ICICI Bank fined ₹12 crore, Kotak ₹3.95 crore ...
# 4   35 lakh weddings in 23 days to generate record...
# 5   Mahadev app key accused arrives from Dubai, he...
# 6   Bankman-Fried's trial delay request over Adder...
# 7                Indian wheat prices hit 8-month high
# 8             Dabur gets ₹321 crore GST demand notice
# 9   'Kill list' of LinkedIn staff being fired was ...
# 10  Planned to make 'Jab...' with Bobby, 'Highway'...
# 11  Ranbir asks photographers to be careful as the...
# 12  Don't break your bank: Zeenat to youngsters on...
# 13  'Kabhi Khushi...' had really bad reviews, I wa...
# 14  Emotional moment: Sandeepa on visiting Kashmir...
# 15  Won't work with Sivakarthikeyan again, he betr...
# 16  What a shame, I'm going to erase today: Direct...
# 17  Kriti Sanon, Allu Arjun's selfie in 'Pushpa' p...
# 18  Taylor Swift's Eras tour security guard joins ...
# 19  Pics show Alia, Ranbir, Kriti, Allu Arjun inte...
# 20  Palestinian, Arab, Muslim Googlers deeply affe...
# 21  Russia fines Zoom $1.18mn for working without ...
# 22  US restricts sale of more advanced AI chips to...
# 23  Apple unveils new Pencil with USB-C port costi...
# 24  Apple's cheaper headset to have less sensors, ...
# 25  Dubai Police unveils driverless, AI-powered pa...
# 26  Bankman-Fried's trial delay request over Adder...
# 27  'Apple AirTag led to multiple murders,' claims...
# 28  'Kill list' of LinkedIn staff being fired was ...
# 29  Facebook, YouTube, Google suppress pro-Palesti...
# 30  Netherlands defeat South Africa in another ups...
# 31  People would tell my parents 'Don't allow her ...
# 32  Are Netherlands doing them in again: Harsha on...
# 33  Rishabh Pant shares video of him running on tr...
# 34  Sri Lanka Cricket lifts ban on Gunathilaka aft...
# 35  Exceptional bowling: Uthappa as SA lose 4 batt...
# 36  PCB files complaint over crowd conduct against...
# 37  Game vs SA could be over before powerplay if E...
# 38  I have never seen Rauf pick wickets like Bumra...
# 39  3 of Netherlands' cricketers playing against S...
#
#                                                  body       category
# 0   Victoria's Secret ex-CEO Leslie Wexner's found...       business
# 1   HDFC Bank's latest advertisement featuring Vig...       business
# 2   PM Narendra Modi at the Global Maritime India ...       business
# 3   The Reserve Bank of India (RBI) has imposed a ...       business
# 4   Traders' body Confederation of All India Trade...       business
# 5   Mrugank Mishra, a key accused in Mahadev betti...       business
# 6   A US court denied FTX Founder Sam Bankman-Frie...       business
# 7   Prices of wheat in India have reached an eight...       business
# 8   Dabur India has received a notice to pay Goods...       business
# 9   A list with names of about 500 employees was l...       business
# 10  Filmmaker Imtiaz Ali revealed that he was plan...  entertainment
# 11  Veteran actress Waheeda Rehman was honoured wi...  entertainment
# 12  Actress Zeenat Aman took to Instagram to share...  entertainment
# 13  Filmmaker Karan Johar said that he was "very d...  entertainment
# 14  Actress Sandeepa Dhar, who was just two when h...  entertainment
# 15  Music composer D Imman said that he will never...  entertainment
# 16  Filmmaker and gay rights activist Onir, expres...  entertainment
# 17  Kriti Sanon received the Best Actress award at...  entertainment
# 18  A security guard who provided protection to si...  entertainment
# 19  The 69th National Film Awards ceremony was hel...  entertainment
# 20  Google CEO Sundar Pichai in an e-mail to emplo...     technology
# 21  Russia has imposed a $1.18 million fine on Zoo...     technology
# 22  The US on Tuesday unveiled plans to restrict t...     technology
# 23  Apple on Tuesday unveiled the new Apple Pencil...     technology
# 24  Apple is reportedly planning to use fewer exte...     technology
# 25  Dubai Police has unveiled a "self-driving" pat...     technology
# 26  A US court denied FTX Founder Sam Bankman-Frie...     technology
# 27  Apple is facing a class action lawsuit in US t...     technology
# 28  A list with names of about 500 employees was l...     technology
# 29  Think tank Hampton Institute alleged that soci...     technology
# 30  Netherlands, the lowest-ranked team in the ong...         sports
# 31  Table tennis player Sutirtha Mukherjee, who al...         sports
# 32  Commentator Harsha Bhogle took to X to state t...         sports
# 33  Wicketkeeper-batter Rishabh Pant, who is under...         sports
# 34  Sri Lanka Cricket (SLC) has lifted ban on Danu...         sports
# 35  Reacting to South Africa losing four batters w...         sports
# 36  The PCB has filed a complaint regarding inappr...         sports
# 37  Former England batter Mark Butcher said Englan...         sports
# 38  Ex-Pakistan captain Wasim Akram said he has ne...         sports
# 39  Netherlands' Sybrand Engelbrecht, Colin Ackerm...         sports

# %%
news_df = news_df.rename(columns = {'body': 'original'})

# %%
basic_clean(news_df.original[0])
# Out:
# "victoria's secret exceo leslie wexner's foundation announced it's cutting its financial and programmatic ties with harvard we are stunned and sickened at the dismal failure of harvard's leadership to take a clearstand against the barbaric murders of innocent israeli civilians the wexner foundation said harvard's leaders were tiptoeing over hamas' attacks against israel it added"

# %%
# test of code for cleaning column
remove_stopwords(tokenize(basic_clean(news_df.original[0])),extra_words = None, exclude_words='not')
# Out:
# "victoria ' s secret exceo leslie wexner ' s foundation announced it ' s cutting its financial and programmatic ties with harvard we are stunned and sickened at the dismal failure of harvard ' s leadership to take a clearstand against the barbaric murders of innocent israeli civilians the wexner foundation said harvard ' s leaders were tiptoeing over hamas ' attacks against israel it added"

# %%
# create new column
i = 0
for line in news_df.original:
    news_df['clean'] = remove_stopwords(tokenize(basic_clean(news_df.original[i])),extra_words = None, exclude_words='not')
    i += 1
# for loop for clean column to iterate through articles
i = 0
for line in news_df.original:
    news_df['clean'][i] = remove_stopwords(tokenize(basic_clean(news_df.original[i])),extra_words = None, exclude_words='not')
    i += 1

# %%
#create the new column first
i = 0
for line in news_df.original:
    news_df['stemmed'] = remove_stopwords(stem(tokenize(basic_clean(news_df.original[i]))),extra_words = None, exclude_words='not')
    i += 1
# fill the new column with stemmed info per index entry    
i = 0
for line in news_df.original:
    news_df['stemmed'][i] = remove_stopwords(stem(tokenize(basic_clean(news_df.original[i]))),extra_words = None, exclude_words='not')
    i += 1

# %%
#create the new column first
i = 0
for line in news_df.original:
    news_df['lemmatized'] = remove_stopwords(lemmatize(tokenize(basic_clean(news_df.original[i]))),extra_words = None, exclude_words='not')
    i += 1
# fill the new column with stemmed info per index entry 
i = 0
for line in news_df.original:
    news_df['lemmatized'][i] = remove_stopwords(lemmatize(tokenize(basic_clean(news_df.original[i]))),extra_words = None, exclude_words='not')
    i += 1

# %% [markdown]
# #### Done.

# %%
news_df

# %% [markdown]
# ### Codeup

# %%
codeup_df = get_blog_articles()
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              article
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...

# %%
codeup_df = codeup_df.rename(columns = {'article': 'original'})

# %%
# create new column for 'cleaned' data
i = 0
for line in codeup_df.original:
    codeup_df['clean'] = remove_stopwords(tokenize(basic_clean(codeup_df.original[i])),extra_words = None, exclude_words='not')
    i += 1
# for loop for clean column to iterate through articles
i = 0
for line in codeup_df.original:
    codeup_df['clean'][i] = remove_stopwords(tokenize(basic_clean(codeup_df.original[i])),extra_words = None, exclude_words='not')
    i += 1

# %%
#create the new column for stemmed data
i = 0
for line in codeup_df.original:
    codeup_df['stemmed'] = remove_stopwords(stem(tokenize(basic_clean(codeup_df.original[i]))),extra_words = None, exclude_words='not')
    i += 1
# fill the new column with stemmed info per index entry    
i = 0
for line in codeup_df.original:
    codeup_df['stemmed'][i] = remove_stopwords(stem(tokenize(basic_clean(codeup_df.original[i]))),extra_words = None, exclude_words='not')
    i += 1

# %%
#create the new column for lemmatized data
i = 0
for line in codeup_df.original:
    codeup_df['lemmatized'] = remove_stopwords(lemmatize(tokenize(basic_clean(codeup_df.original[i]))),extra_words = None, exclude_words='not')
    i += 1
# fill the new column with stemmed info per index entry 
i = 0
for line in codeup_df.original:
    codeup_df['lemmatized'][i] = remove_stopwords(lemmatize(tokenize(basic_clean(codeup_df.original[i]))),extra_words = None, exclude_words='not')
    i += 1

# %% [markdown]
# #### Done.

# %%
# testing if for loops worked
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...
#
#                                                clean  \
# 0  may is traditionally known as asian american a...
# 1  women in tech panelist spotlight magdalena rah...
# 2  women in tech panelist spotlight rachel robbin...
# 3  women in tech panelist spotlight sarah mellor ...
# 4  women in tech panelist spotlight madeleine cap...
# 5  black excellence in tech panelist spotlight wi...
#
#                                              stemmed  \
# 0  may is tradit known as asian american and paci...
# 1  women in tech panelist spotlight magdalena rah...
# 2  women in tech panelist spotlight rachel robbin...
# 3  women in tech panelist spotlight sarah mellor ...
# 4  women in tech panelist spotlight madelein capp...
# 5  black excel in tech panelist spotlight wilmari...
#
#                                           lemmatized
# 0  may is traditionally known a asian american an...
# 1  woman in tech panelist spotlight magdalena rah...
# 2  woman in tech panelist spotlight rachel robbin...
# 3  woman in tech panelist spotlight sarah mellor ...
# 4  woman in tech panelist spotlight madeleine cap...
# 5  black excellence in tech panelist spotlight wi...

# %% [markdown]
# ## Ask yourself:
#
# - If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
#   - Definitely lemmatized text here, with such a small file, the run time shouldn't be significant enough to even notice.
# - If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
#   - I still believe this is within a size margin to lemmatize, once we start getting into GB further consideration may be needed.
# - If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?
#   - this is tough, although I personally prefer to lemmatize the data, stemmed would be significantly faster from such a large corpus. There would likely have to be more emphasis before attempting to extract the data so no return pulls are needed.

# %% [markdown]
# # Personal Bonus

# %% [markdown]
# #### Testing functions to ensure reciprocity

# %%
from acquire import get_blog_articles, get_news_article
from prepare import basic_clean, create_clean, create_lemmatize, create_stemmed, remove_stopwords, tokenize, stem, lemmatize
import pandas as pd

# %% [markdown]
# ## News

# %%
news_df = get_news_article()
news_df = news_df.rename(columns = {'body': 'original'})
news_df['clean'] = create_clean(news_df, extra_words = None, exclude_words = 'not')['clean']
news_df['stemmed'] = create_stemmed(news_df, extra_words = None, exclude_words = 'not')['stemmed']
news_df['lemmatized'] = create_lemmatize(news_df, extra_words = None, exclude_words = 'not')['lemmatized']
news_df
# Out:
#                                                 title  \
# 0   Victoria's Secret ex-CEO cuts Harvard ties for...
# 1   HDFC Bank's Vigil Aunty ad gets criticism for ...
# 2   IMEC big opportunity for investors to partner ...
# 3   ICICI Bank fined ₹12 crore, Kotak ₹3.95 crore ...
# 4   35 lakh weddings in 23 days to generate record...
# 5   Mahadev app key accused arrives from Dubai, he...
# 6   Bankman-Fried's trial delay request over Adder...
# 7                Indian wheat prices hit 8-month high
# 8             Dabur gets ₹321 crore GST demand notice
# 9   'Kill list' of LinkedIn staff being fired was ...
# 10  Planned to make 'Jab...' with Bobby, 'Highway'...
# 11  Ranbir asks photographers to be careful as the...
# 12  Don't break your bank: Zeenat to youngsters on...
# 13  'Kabhi Khushi...' had really bad reviews, I wa...
# 14  Emotional moment: Sandeepa on visiting Kashmir...
# 15  Won't work with Sivakarthikeyan again, he betr...
# 16  What a shame, I'm going to erase today: Direct...
# 17  Kriti Sanon, Allu Arjun's selfie in 'Pushpa' p...
# 18  Taylor Swift's Eras tour security guard joins ...
# 19  Pics show Alia, Ranbir, Kriti, Allu Arjun inte...
# 20  Palestinian, Arab, Muslim Googlers deeply affe...
# 21  Russia fines Zoom $1.18mn for working without ...
# 22  US restricts sale of more advanced AI chips to...
# 23  Apple unveils new Pencil with USB-C port costi...
# 24  Apple's cheaper headset to have less sensors, ...
# 25  Dubai Police unveils driverless, AI-powered pa...
# 26  Bankman-Fried's trial delay request over Adder...
# 27  'Apple AirTag led to multiple murders,' claims...
# 28  'Kill list' of LinkedIn staff being fired was ...
# 29  Facebook, YouTube, Google suppress pro-Palesti...
# 30  Netherlands defeat South Africa in another ups...
# 31  People would tell my parents 'Don't allow her ...
# 32  Are Netherlands doing them in again: Harsha on...
# 33  Rishabh Pant shares video of him running on tr...
# 34  Sri Lanka Cricket lifts ban on Gunathilaka aft...
# 35  Exceptional bowling: Uthappa as SA lose 4 batt...
# 36  PCB files complaint over crowd conduct against...
# 37  Game vs SA could be over before powerplay if E...
# 38  I have never seen Rauf pick wickets like Bumra...
# 39  3 of Netherlands' cricketers playing against S...
#
#                                              original       category  \
# 0   Victoria's Secret ex-CEO Leslie Wexner's found...       business
# 1   HDFC Bank's latest advertisement featuring Vig...       business
# 2   PM Narendra Modi at the Global Maritime India ...       business
# 3   The Reserve Bank of India (RBI) has imposed a ...       business
# 4   Traders' body Confederation of All India Trade...       business
# 5   Mrugank Mishra, a key accused in Mahadev betti...       business
# 6   A US court denied FTX Founder Sam Bankman-Frie...       business
# 7   Prices of wheat in India have reached an eight...       business
# 8   Dabur India has received a notice to pay Goods...       business
# 9   A list with names of about 500 employees was l...       business
# 10  Filmmaker Imtiaz Ali revealed that he was plan...  entertainment
# 11  Veteran actress Waheeda Rehman was honoured wi...  entertainment
# 12  Actress Zeenat Aman took to Instagram to share...  entertainment
# 13  Filmmaker Karan Johar said that he was "very d...  entertainment
# 14  Actress Sandeepa Dhar, who was just two when h...  entertainment
# 15  Music composer D Imman said that he will never...  entertainment
# 16  Filmmaker and gay rights activist Onir, expres...  entertainment
# 17  Kriti Sanon received the Best Actress award at...  entertainment
# 18  A security guard who provided protection to si...  entertainment
# 19  The 69th National Film Awards ceremony was hel...  entertainment
# 20  Google CEO Sundar Pichai in an e-mail to emplo...     technology
# 21  Russia has imposed a $1.18 million fine on Zoo...     technology
# 22  The US on Tuesday unveiled plans to restrict t...     technology
# 23  Apple on Tuesday unveiled the new Apple Pencil...     technology
# 24  Apple is reportedly planning to use fewer exte...     technology
# 25  Dubai Police has unveiled a "self-driving" pat...     technology
# 26  A US court denied FTX Founder Sam Bankman-Frie...     technology
# 27  Apple is facing a class action lawsuit in US t...     technology
# 28  A list with names of about 500 employees was l...     technology
# 29  Think tank Hampton Institute alleged that soci...     technology
# 30  Netherlands, the lowest-ranked team in the ong...         sports
# 31  Table tennis player Sutirtha Mukherjee, who al...         sports
# 32  Commentator Harsha Bhogle took to X to state t...         sports
# 33  Wicketkeeper-batter Rishabh Pant, who is under...         sports
# 34  Sri Lanka Cricket (SLC) has lifted ban on Danu...         sports
# 35  Reacting to South Africa losing four batters w...         sports
# 36  The PCB has filed a complaint regarding inappr...         sports
# 37  Former England batter Mark Butcher said Englan...         sports
# 38  Ex-Pakistan captain Wasim Akram said he has ne...         sports
# 39  Netherlands' Sybrand Engelbrecht, Colin Ackerm...         sports
#
#                                                 clean  \
# 0   victoria ' s secret exceo leslie wexner ' s fo...
# 1   hdfc bank ' s latest advertisement featuring v...
# 2   pm narendra modi at the global maritime india ...
# 3   the reserve bank of india rbi has imposed a pe...
# 4   traders ' body confederation of all india trad...
# 5   mrugank mishra a key accused in mahadev bettin...
# 6   a us court denied ftx founder sam bankmanfried...
# 7   prices of wheat in india have reached an eight...
# 8   dabur india has received a notice to pay goods...
# 9   a list with names of about 500 employees was l...
# 10  filmmaker imtiaz ali revealed that he was plan...
# 11  veteran actress waheeda rehman was honoured wi...
# 12  actress zeenat aman took to instagram to share...
# 13  filmmaker karan johar said that he was very de...
# 14  actress sandeepa dhar who was just two when he...
# 15  music composer d imman said that he will never...
# 16  filmmaker and gay rights activist onir express...
# 17  kriti sanon received the best actress award at...
# 18  a security guard who provided protection to si...
# 19  the 69th national film awards ceremony was hel...
# 20  google ceo sundar pichai in an email to employ...
# 21  russia has imposed a 118 million fine on zoom ...
# 22  the us on tuesday unveiled plans to restrict t...
# 23  apple on tuesday unveiled the new apple pencil...
# 24  apple is reportedly planning to use fewer exte...
# 25  dubai police has unveiled a selfdriving patrol...
# 26  a us court denied ftx founder sam bankmanfried...
# 27  apple is facing a class action lawsuit in us t...
# 28  a list with names of about 500 employees was l...
# 29  think tank hampton institute alleged that soci...
# 30  netherlands the lowestranked team in the ongoi...
# 31  table tennis player sutirtha mukherjee who alo...
# 32  commentator harsha bhogle took to x to state t...
# 33  wicketkeeperbatter rishabh pant who is undergo...
# 34  sri lanka cricket slc has lifted ban on danush...
# 35  reacting to south africa losing four batters w...
# 36  the pcb has filed a complaint regarding inappr...
# 37  former england batter mark butcher said englan...
# 38  expakistan captain wasim akram said he has nev...
# 39  netherlands ' sybrand engelbrecht colin ackerm...
#
#                                               stemmed  \
# 0   victoria ' s secret exceo lesli wexner ' s fou...
# 1   hdfc bank ' s latest advertis featur vigil aun...
# 2   pm narendra modi at the global maritim india s...
# 3   the reserv bank of india rbi ha impos a penalt...
# 4   trader ' bodi confeder of all india trader cai...
# 5   mrugank mishra a key accus in mahadev bet app ...
# 6   a us court deni ftx founder sam bankmanfri ' s...
# 7   price of wheat in india have reach an eightmon...
# 8   dabur india ha receiv a notic to pay good and ...
# 9   a list with name of about 500 employe wa leak ...
# 10  filmmak imtiaz ali reveal that he wa plan to m...
# 11  veteran actress waheeda rehman wa honour with ...
# 12  actress zeenat aman took to instagram to share...
# 13  filmmak karan johar said that he wa veri depre...
# 14  actress sandeepa dhar who wa just two when her...
# 15  music compos d imman said that he will never w...
# 16  filmmak and gay right activist onir express hi...
# 17  kriti sanon receiv the best actress award at t...
# 18  a secur guard who provid protect to singer and...
# 19  the 69th nation film award ceremoni wa held in...
# 20  googl ceo sundar pichai in an email to employe...
# 21  russia ha impos a 118 million fine on zoom for...
# 22  the us on tuesday unveil plan to restrict the ...
# 23  appl on tuesday unveil the new appl pencil wit...
# 24  appl is reportedli plan to use fewer extern ca...
# 25  dubai polic ha unveil a selfdriv patrol vehicl...
# 26  a us court deni ftx founder sam bankmanfri ' s...
# 27  appl is face a class action lawsuit in us that...
# 28  a list with name of about 500 employe wa leak ...
# 29  think tank hampton institut alleg that social ...
# 30  netherland the lowestrank team in the ongo odi...
# 31  tabl tenni player sutirtha mukherje who along ...
# 32  comment harsha bhogl took to x to state that b...
# 33  wicketkeeperbatt rishabh pant who is undergo r...
# 34  sri lanka cricket slc ha lift ban on danushka ...
# 35  react to south africa lose four batter within ...
# 36  the pcb ha file a complaint regard inappropri ...
# 37  former england batter mark butcher said englan...
# 38  expakistan captain wasim akram said he ha neve...
# 39  netherland ' sybrand engelbrecht colin ackerma...
#
#                                            lemmatized
# 0   victoria ' s secret exceo leslie wexner ' s fo...
# 1   hdfc bank ' s latest advertisement featuring v...
# 2   pm narendra modi at the global maritime india ...
# 3   the reserve bank of india rbi ha imposed a pen...
# 4   trader ' body confederation of all india trade...
# 5   mrugank mishra a key accused in mahadev bettin...
# 6   a u court denied ftx founder sam bankmanfried ...
# 7   price of wheat in india have reached an eightm...
# 8   dabur india ha received a notice to pay good a...
# 9   a list with name of about 500 employee wa leak...
# 10  filmmaker imtiaz ali revealed that he wa plann...
# 11  veteran actress waheeda rehman wa honoured wit...
# 12  actress zeenat aman took to instagram to share...
# 13  filmmaker karan johar said that he wa very dep...
# 14  actress sandeepa dhar who wa just two when her...
# 15  music composer d imman said that he will never...
# 16  filmmaker and gay right activist onir expressi...
# 17  kriti sanon received the best actress award at...
# 18  a security guard who provided protection to si...
# 19  the 69th national film award ceremony wa held ...
# 20  google ceo sundar pichai in an email to employ...
# 21  russia ha imposed a 118 million fine on zoom f...
# 22  the u on tuesday unveiled plan to restrict the...
# 23  apple on tuesday unveiled the new apple pencil...
# 24  apple is reportedly planning to use fewer exte...
# 25  dubai police ha unveiled a selfdriving patrol ...
# 26  a u court denied ftx founder sam bankmanfried ...
# 27  apple is facing a class action lawsuit in u th...
# 28  a list with name of about 500 employee wa leak...
# 29  think tank hampton institute alleged that soci...
# 30  netherlands the lowestranked team in the ongoi...
# 31  table tennis player sutirtha mukherjee who alo...
# 32  commentator harsha bhogle took to x to state t...
# 33  wicketkeeperbatter rishabh pant who is undergo...
# 34  sri lanka cricket slc ha lifted ban on danushk...
# 35  reacting to south africa losing four batter wi...
# 36  the pcb ha filed a complaint regarding inappro...
# 37  former england batter mark butcher said englan...
# 38  expakistan captain wasim akram said he ha neve...
# 39  netherlands ' sybrand engelbrecht colin ackerm...

# %% [markdown]
# ## Codeup

# %%
codeup_df = get_blog_articles()
codeup_df = codeup_df.rename(columns = {'article': 'original'})
codeup_df['clean'] = create_clean(codeup_df, extra_words = None, exclude_words = 'not')['clean']
codeup_df['stemmed'] = create_stemmed(codeup_df, extra_words = None, exclude_words = 'not')['stemmed']
codeup_df['lemmatized'] = create_lemmatize(codeup_df, extra_words = None, exclude_words = 'not')['lemmatized']
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...
#
#                                                clean  \
# 0  may is traditionally known as asian american a...
# 1  women in tech panelist spotlight magdalena rah...
# 2  women in tech panelist spotlight rachel robbin...
# 3  women in tech panelist spotlight sarah mellor ...
# 4  women in tech panelist spotlight madeleine cap...
# 5  black excellence in tech panelist spotlight wi...
#
#                                              stemmed  \
# 0  may is tradit known as asian american and paci...
# 1  women in tech panelist spotlight magdalena rah...
# 2  women in tech panelist spotlight rachel robbin...
# 3  women in tech panelist spotlight sarah mellor ...
# 4  women in tech panelist spotlight madelein capp...
# 5  black excel in tech panelist spotlight wilmari...
#
#                                           lemmatized
# 0  may is traditionally known a asian american an...
# 1  woman in tech panelist spotlight magdalena rah...
# 2  woman in tech panelist spotlight rachel robbin...
# 3  woman in tech panelist spotlight sarah mellor ...
# 4  woman in tech panelist spotlight madeleine cap...
# 5  black excellence in tech panelist spotlight wi...
